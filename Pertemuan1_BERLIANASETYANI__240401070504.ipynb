# %%
# Nama: Berliana Setyani | NIM: 240401070504 | Kelas: IF-401

# SEL 1: Output sederhana
print("Hello, Data Science!")


# SEL 2: Variabel & tipe data
nama = "Mahasiswa Informatika"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")


# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","Github"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")


# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Budi", "Informatika", 2024))

# Kesimpulan:
# Notebook ini memperkenalkan dasar-dasar pemrograman Python, meliputi: output sederhana menggunakan print(), penggunaan variabel dan tipe data (string, integer), pemanfaatan list dan perulangan for untuk iterasi data, dan pembuatan dan pemanggilan fungsi Python kustom.
# Temuan utama: Kode yang disajikan menunjukkan sintaks dasar Python untuk tugas-tugas fundamental.
# Out:
# Hello, Data Science!
# Halo, Mahasiswa Informatika angkatan 2024!
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. Github
# Budi | Informatika | 2024
